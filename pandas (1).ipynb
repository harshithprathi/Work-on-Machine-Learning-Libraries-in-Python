# %%
import pandas as pd

# %%
url="https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/titanic.csv"

# %%
dataframe=pd.read_csv(url)

# %%
dataframe
# Out:
#                                                Name PClass    Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                       Allison, Miss Helen Loraine    1st   2.00  female
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                     Allison, Master Hudson Trevor    1st   0.92    male
# ...                                             ...    ...    ...     ...
# 1308                             Zakarian, Mr Artun    3rd  27.00    male
# 1309                         Zakarian, Mr Maprieder    3rd  26.00    male
# 1310                               Zenni, Mr Philip    3rd  22.00    male
# 1311                               Lievens, Mr Rene    3rd  24.00    male
# 1312                                 Zimmerman, Leo    3rd  29.00    male
#
#       Survived  SexCode
# 0            1        1
# 1            0        1
# ...

# %%
dataframe.head()
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %%
dataframe.tail()
# Out:
#                         Name PClass   Age   Sex  Survived  SexCode
# 1308      Zakarian, Mr Artun    3rd  27.0  male         0        0
# 1309  Zakarian, Mr Maprieder    3rd  26.0  male         0        0
# 1310        Zenni, Mr Philip    3rd  22.0  male         0        0
# 1311        Lievens, Mr Rene    3rd  24.0  male         0        0
# 1312          Zimmerman, Leo    3rd  29.0  male         0        0

# %%
dataframe.head(10)
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
# 5                             Anderson, Mr Harry    1st  47.00    male
# 6               Andrews, Miss Kornelia Theodosia    1st  63.00  female
# 7                         Andrews, Mr Thomas, jr    1st  39.00    male
# 8   Appleton, Mrs Edward Dale (Charlotte Lamson)    1st  58.00  female
# 9                         Artagaveytia, Mr Ramon    1st  71.00    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0
# 5         1        0
# 6         1        1
# ...

# %%
dataframe.head(11)
# Out:
#                                              Name PClass    Age     Sex  \
# 0                    Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                     Allison, Miss Helen Loraine    1st   2.00  female
# 2             Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3   Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                   Allison, Master Hudson Trevor    1st   0.92    male
# 5                              Anderson, Mr Harry    1st  47.00    male
# 6                Andrews, Miss Kornelia Theodosia    1st  63.00  female
# 7                          Andrews, Mr Thomas, jr    1st  39.00    male
# 8    Appleton, Mrs Edward Dale (Charlotte Lamson)    1st  58.00  female
# 9                          Artagaveytia, Mr Ramon    1st  71.00    male
# 10                      Astor, Colonel John Jacob    1st  47.00    male
#
#     Survived  SexCode
# 0          1        1
# 1          0        1
# 2          0        0
# ...

# %%
datafr=pd.DataFrame()

# %%
datafr["Name"]=["harshith","varun", "vamshi", "sid", "akshay"]

# %%
datafr
# Out:
#        Name
# 0  harshith
# 1     varun
# 2    vamshi
# 3       sid
# 4    akshay

# %%
datafr["Age"]=[19,20,19,19,19]
datafr
# Out:
#    Age
# 0   19
# 1   20
# 2   19
# 3   19
# 4   19

# %%
new_team=pd.Series(['mukul','45'], index=['Name','Age'])
datafr.append(new_team, ignore_index=True)
# Out:
#   Age   Name
# 0  19    NaN
# 1  20    NaN
# 2  19    NaN
# 3  19    NaN
# 4  19    NaN
# 5  45  mukul

# %%
new_team=pd.Series(['mukul','45'], index=['Name','Age'])
datafr.append(new_team, ignore_index=True)
# Out:
#   Age   Name
# 0  19    NaN
# 1  20    NaN
# 2  19    NaN
# 3  19    NaN
# 4  19    NaN
# 5  45  mukul

# %%
datafr.append(new_team, ignore_index=True)
# Out:
#        Name Age
# 0  harshith  19
# 1     varun  20
# 2    vamshi  19
# 3       sid  19
# 4    akshay  19
# 5     mukul  45

# %%
datafr.shape
# Out:
# (5, 2)

# %%
datafr.describe()
# Out:
#              Age
# count   5.000000
# mean   19.200000
# std     0.447214
# min    19.000000
# 25%    19.000000
# 50%    19.000000
# 75%    19.000000
# max    20.000000

# %%
datafr.iloc[0:1]
# Out:
#        Name  Age
# 0  harshith   19

# %%
datafr.set_index(datafr["Age"])
# Out:
#          Name  Age
# Age
# 19   harshith   19
# 20      varun   20
# 19     vamshi   19
# 19        sid   19
# 19     akshay   19

# %%
dataframe[dataframe['Sex']=='female'].head(10)
# Out:
#                                                 Name PClass   Age     Sex  \
# 0                       Allen, Miss Elisabeth Walton    1st  29.0  female
# 1                        Allison, Miss Helen Loraine    1st   2.0  female
# 3      Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
# 6                   Andrews, Miss Kornelia Theodosia    1st  63.0  female
# 8       Appleton, Mrs Edward Dale (Charlotte Lamson)    1st  58.0  female
# 11  Astor, Mrs John Jacob (Madeleine Talmadge Force)    1st  19.0  female
# 12                      Aubert, Mrs Leontine Pauline    1st   NaN  female
# 15    Baxter, Mrs James (Helene DeLaudeniere Chaput)    1st  50.0  female
# 19   Beckwith, Mrs Richard Leonard (Sallie Monypeny)    1st  47.0  female
# 23            Bishop, Mrs Dickinson H (Helen Walton)    1st  19.0  female
#
#     Survived  SexCode
# 0          1        1
# 1          0        1
# 3          0        1
# 6          1        1
# 8          1        1
# ...

# %%
dataframe[dataframe['Sex']=='male'].head(10)
# Out:
#                                    Name PClass    Age   Sex  Survived  SexCode
# 2   Allison, Mr Hudson Joshua Creighton    1st  30.00  male         0        0
# 4         Allison, Master Hudson Trevor    1st   0.92  male         1        0
# 5                    Anderson, Mr Harry    1st  47.00  male         1        0
# 7                Andrews, Mr Thomas, jr    1st  39.00  male         0        0
# 9                Artagaveytia, Mr Ramon    1st  71.00  male         0        0
# 10            Astor, Colonel John Jacob    1st  47.00  male         0        0
# 13             Barkworth, Mr Algernon H    1st    NaN  male         1        0
# 14                   Baumann, Mr John D    1st    NaN  male         0        0
# 16              Baxter, Mr Quigg Edmond    1st  24.00  male         0        0
# 17                  Beattie, Mr Thomson    1st  36.00  male         0        0

# %%
dataframe[(dataframe['Sex']=='male') & (dataframe['Age']>=50)].count()
# Out:
# Name        48
# PClass      48
# Age         48
# Sex         48
# Survived    48
# SexCode     48
# dtype: int64

# %%
dataframe['Sex'].replace('male','man')
# Out:
# 0       female
# 1       female
# 2          man
# 3       female
# 4          man
#          ...
# 1308       man
# 1309       man
# 1310       man
# 1311       man
# 1312       man
# Name: Sex, Length: 1313, dtype: object

# %%
dataframe.rename(columns={'Survived':'ML'})
# Out:
#                                                Name PClass    Age     Sex  ML  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00  female   1
# 1                       Allison, Miss Helen Loraine    1st   2.00  female   0
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00    male   0
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female   0
# 4                     Allison, Master Hudson Trevor    1st   0.92    male   1
# ...                                             ...    ...    ...     ...  ..
# 1308                             Zakarian, Mr Artun    3rd  27.00    male   0
# 1309                         Zakarian, Mr Maprieder    3rd  26.00    male   0
# 1310                               Zenni, Mr Philip    3rd  22.00    male   0
# 1311                               Lievens, Mr Rene    3rd  24.00    male   0
# 1312                                 Zimmerman, Leo    3rd  29.00    male   0
#
#       SexCode
# 0           1
# ...

# %%
import pandas as pd
df=pd.DataFrame()

# %%
df["name"]=["harshith","vamshi","Varun"]

# %%
df
# Out:
#        name
# 0  harshith
# 1    vamshi
# 2     Varun

# %%
df.iloc[:,0]
# Out:
# 0    harshith
# 1      vamshi
# 2       Varun
# Name: name, dtype: object

# %%
df["Age"]=[19,19,20]

# %%
df
# Out:
#        name  Age
# 0  harshith   19
# 1    vamshi   19
# 2     Varun   20

# %%
df["Age"].max()
# Out:
# 20

# %%
df["Age"].min()
# Out:
# 19

# %%
df["Age"].sum()
# Out:
# 58

# %%
df["Age"].count()
# Out:
# 3

# %%
df["Age"].mean()
# Out:
# 19.333333333333332

# %%
url="https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/titanic.csv"
dataframe=pd.read_csv(url)
dataframe
# Out:
#                                                Name PClass    Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                       Allison, Miss Helen Loraine    1st   2.00  female
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                     Allison, Master Hudson Trevor    1st   0.92    male
# ...                                             ...    ...    ...     ...
# 1308                             Zakarian, Mr Artun    3rd  27.00    male
# 1309                         Zakarian, Mr Maprieder    3rd  26.00    male
# 1310                               Zenni, Mr Philip    3rd  22.00    male
# 1311                               Lievens, Mr Rene    3rd  24.00    male
# 1312                                 Zimmerman, Leo    3rd  29.00    male
#
#       Survived  SexCode
# 0            1        1
# 1            0        1
# ...

# %%
dataframe["Sex"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
dataframe["Name"].unique()
# Out:
# array(['Allen, Miss Elisabeth Walton', 'Allison, Miss Helen Loraine',
#        'Allison, Mr Hudson Joshua Creighton', ..., 'Zenni, Mr Philip',
#        'Lievens, Mr Rene', 'Zimmerman, Leo'], dtype=object)

# %%
dataframe["Sex"].value_counts()
# Out:
# male      851
# female    462
# Name: Sex, dtype: int64

# %%
dataframe[dataframe["Age"].isnull()]
# Out:
#                               Name PClass  Age     Sex  Survived  SexCode
# 12    Aubert, Mrs Leontine Pauline    1st  NaN  female         1        1
# 13        Barkworth, Mr Algernon H    1st  NaN    male         1        0
# 14              Baumann, Mr John D    1st  NaN    male         0        0
# 29         Borebank, Mr John James    1st  NaN    male         0        0
# 32              Bradley, Mr George    1st  NaN    male         1        0
# ...                            ...    ...  ...     ...       ...      ...
# 1300         Wiseman, Mr Phillippe    3rd  NaN    male         0        0
# 1302             Yalsevac, Mr Ivan    3rd  NaN    male         1        0
# 1305            Youssef, Mr Gerios    3rd  NaN    male         0        0
# 1306           Zabour, Miss Hileni    3rd  NaN  female         0        1
# 1307           Zabour, Miss Tamini    3rd  NaN  female         0        1
#
# [557 rows x 6 columns]

# %%
import numpy as np
dataframe["Sex"]=dataframe["Sex"].replace('male',np.nan)

# %%
dataframe
# Out:
#                                                Name PClass    Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                       Allison, Miss Helen Loraine    1st   2.00  female
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00     NaN
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                     Allison, Master Hudson Trevor    1st   0.92     NaN
# ...                                             ...    ...    ...     ...
# 1308                             Zakarian, Mr Artun    3rd  27.00     NaN
# 1309                         Zakarian, Mr Maprieder    3rd  26.00     NaN
# 1310                               Zenni, Mr Philip    3rd  22.00     NaN
# 1311                               Lievens, Mr Rene    3rd  24.00     NaN
# 1312                                 Zimmerman, Leo    3rd  29.00     NaN
#
#       Survived  SexCode
# 0            1        1
# 1            0        1
# ...

# %%
df.drop("Age",axis=1)
# Out:
#        name
# 0  harshith
# 1    vamshi
# 2     Varun

# %%
import matplotlib.pyplot as plt
plt.scatter(10,10)
plt.show()

# %%
import pandas as pd
df=pd.DataFrame()
df["Name"]=["harshith", "bobby", "jitu", "sai", "teja"]
df["Age"]=[19,19,14,21,16]
def replace_name(val):
    if "Name"=="harshith":
        return 0
    else:
        return 1
df["Name"]=df["Name"].apply(replace_name,10)
df["Name"]
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Name, dtype: int64
